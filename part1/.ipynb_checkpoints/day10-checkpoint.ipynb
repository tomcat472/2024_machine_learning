# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.linspace(0,10,100)
plt.plot(x,np.cosh(x));

# %%
x=np.linspace(0,10,1000)
y=np.sin(x)
plt.plot(x,y,color='r');

# %%
plt.scatter(x[:30],y[:30]);

# %%
plt.scatter(x[::10],y[::10]);

# %%
plt.plot(x,np.sin(x-0),color='b')
plt.plot(x,np.sin(x-1),color='r')
plt.plot(x,np.sin(x-2),color='k');

# %%
plt.plot(x,x+0,'-g')
plt.plot(x,x+1,'--c')
plt.plot(x,x+2,'-.k')
plt.plot(x,x+3,':r');

# %%
plt.style.use('classic')
x=np.linspace(0,100,1000)
y=np.cumsum(np.random.randn(1000,5),0)
plt.plot(x,y)
plt.legend('ABCDE',ncol=2,loc='upper left');

# %%
sns.set()
plt.plot(x,y)
plt.legend('ABCDEF',ncol=2,loc='upper left');

# %%
x=pd.Series(50*np.random.randn(5000))
y=pd.Series(200*np.random.randn(5000))
z=pd.Series(100*np.random.randn(5000)+500)
data=pd.DataFrame({'x':x,'y':y,'z':z})
data.head()
# Out:
#             x           y           z
# 0    7.417208   81.960875  496.248292
# 1 -108.263459   18.198700  287.244156
# 2    1.196807  297.112311  566.549623
# 3   56.864126  129.791052  528.062497
# 4   -3.215882    6.184323  197.798636

# %%
plt.hist(x,density=True)
plt.hist(y,density=True,alpha=0.5);

# %%
data=pd.DataFrame({'x':x,'y':y,'z':z})
for col in data.columns:
    plt.hist(data[col],density=True,alpha=0.5)

# %%
for col in data.columns:
    plt.hist(data[col],density=True,alpha=0.5)

# %%
for col in data.columns:
    sns.kdeplot(data[col],fill=True)

# %%
for col in data.columns:
    sns.displot(data[col])

# %%
with sns.axes_style('white'):
    sns.jointplot(x=data['x'],y=data['y'],data=data,kind='kde');

# %%
sns.pairplot(data);

# %%
iris=sns.load_dataset('iris')
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
sns.pairplot(iris,hue='species');

# %%
from bokeh.plotting import figure,output_file,show

# %%
output_file('myplot.html')
p=figure(outer_width=400,outer_height=400,title='line')
p.line([2,4,6,8,10],[1,3,5,7,9],line_width=0.7)
show(p)

# %%
p2=figure(title='My Plot',x_axis_label='X_value',y_axis_label='Y_value')
x=np.linspace(0,10,30)
y1=np.sin(x)
y2=np.cos(x)
p2.line(x,y1,line_color='blue')
p2.circle(x,x,fill_color='red',size=5)
p2.line(x,y2,line_width=3,line_color='red')
p2.triangle(x,x**2,color='black')
show(p2)

# %%
from bokeh.layouts import gridplot
x=np.linspace(0,6*np.pi,100)
y0=np.sin(x)
y1=np.cos(x)
y2=np.sin(x)+np.cos(x)-1

s1=figure(width=400)
s1.circle(x,y0,size=10,color='navy',alpha=0.5)

s2=figure(width=400)
s2.triangle(x,y1,size=10,color='firebrick',alpha=0.5)

s3=figure(width=400)
s3.square(x,y2,size=10,color='olive',alpha=0.5)

p=gridplot([[s1,s2,s3]])

show(p)
