# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('datasets/adult.csv')
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df['income']
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: income, Length: 48842, dtype: object

# %%
df[['income','age']]
# Out:
#       income  age
# 0      <=50K   25
# 1      <=50K   38
# 2       >50K   28
# 3       >50K   44
# 4      <=50K   18
# ...      ...  ...
# 48837  <=50K   27
# 48838   >50K   40
# 48839  <=50K   58
# 48840  <=50K   22
# 48841   >50K   52
#
# [48842 rows x 2 columns]

# %%
df.loc[:,['income','age']]
# Out:
#       income  age
# 0      <=50K   25
# 1      <=50K   38
# 2       >50K   28
# 3       >50K   44
# 4      <=50K   18
# ...      ...  ...
# 48837  <=50K   27
# 48838   >50K   40
# 48839  <=50K   58
# 48840  <=50K   22
# 48841   >50K   52
#
# [48842 rows x 2 columns]

# %%
df['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
df.income=='>50K'
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 48837    False
# 48838     True
# 48839    False
# 48840    False
# 48841     True
# Name: income, Length: 48842, dtype: bool

# %%
df[df.income=='>50K']
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 2       28         Local-gov  336951    Assoc-acdm               12
# 3       44           Private  160323  Some-college               10
# 7       63  Self-emp-not-inc  104626   Prof-school               15
# 10      65           Private  184454       HS-grad                9
# 14      48           Private  279724       HS-grad                9
# ...    ...               ...     ...           ...              ...
# 48820   71                 ?  287372     Doctorate               16
# 48826   39         Local-gov  111499    Assoc-acdm               12
# 48835   53           Private  321865       Masters               14
# 48838   40           Private  154374       HS-grad                9
# 48841   52      Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# ...

# %%
df[df.income=='>50K'].reset_index()
# Out:
#        index  age         workclass  fnlwgt     education  educational-num  \
# 0          2   28         Local-gov  336951    Assoc-acdm               12
# 1          3   44           Private  160323  Some-college               10
# 2          7   63  Self-emp-not-inc  104626   Prof-school               15
# 3         10   65           Private  184454       HS-grad                9
# 4         14   48           Private  279724       HS-grad                9
# ...      ...  ...               ...     ...           ...              ...
# 11682  48820   71                 ?  287372     Doctorate               16
# 11683  48826   39         Local-gov  111499    Assoc-acdm               12
# 11684  48835   53           Private  321865       Masters               14
# 11685  48838   40           Private  154374       HS-grad                9
# 11686  48841   52      Self-emp-inc  287927       HS-grad                9
#
# ...

# %%
idx=df.income=='>50K'
idx
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 48837    False
# 48838     True
# 48839    False
# 48840    False
# 48841     True
# Name: income, Length: 48842, dtype: bool

# %%
df['income'].loc[idx]=-1
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\2898100095.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['income'].loc[idx]=-1

# %%
df['income'].loc[~idx]=1
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\3443458778.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['income'].loc[~idx]=1

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.income
# Out:
# 0         1
# 1         1
# 2        -1
# 3        -1
# 4         1
#          ..
# 48837     1
# 48838    -1
# 48839     1
# 48840     1
# 48841    -1
# Name: income, Length: 48842, dtype: object

# %%
df.income.unique()
# Out:
# array([1, -1], dtype=object)

# %%
df.age.unique()
# Out:
# array([25, 38, 28, 44, 18, 34, 29, 63, 24, 55, 65, 36, 26, 58, 48, 43, 20,
#        37, 40, 72, 45, 22, 23, 54, 32, 46, 56, 17, 39, 52, 21, 42, 33, 30,
#        47, 41, 19, 69, 50, 31, 59, 49, 51, 27, 57, 61, 64, 79, 73, 53, 77,
#        80, 62, 35, 68, 66, 75, 60, 67, 71, 70, 90, 81, 74, 78, 82, 83, 85,
#        76, 84, 89, 88, 87, 86], dtype=int64)

# %%
df.age.unique().size
# Out:
# 74

# %%
df=pd.get_dummies(df,columns=['gender'])

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  \
# 0           Never-married  Machine-op-inspct    Own-child  Black
# ...

# %%
df.occupation.isnull().sum()
# Out:
# 0

# %%
df2=pd.get_dummies(df,columns=['race','marital-status'])

# %%
df2
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#               occupation relationship  capital-gain  capital-loss  \
# 0      Machine-op-inspct    Own-child             0             0
# ...

# %%
df2.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'occupation', 'relationship', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'native-country', 'income', 'gender_Female',
#        'gender_Male', 'race_Amer-Indian-Eskimo', 'race_Asian-Pac-Islander',
#        'race_Black', 'race_Other', 'race_White', 'marital-status_Divorced',
#        'marital-status_Married-AF-spouse', 'marital-status_Married-civ-spouse',
#        'marital-status_Married-spouse-absent', 'marital-status_Never-married',
#        'marital-status_Separated', 'marital-status_Widowed'],
#       dtype='object')

# %%
df2['marital-status_Never-married'].value_counts()
# Out:
# 0    32725
# 1    16117
# Name: marital-status_Never-married, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 26 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   48842 non-null  int64
#  1   workclass                             48842 non-null  object
#  2   fnlwgt                                48842 non-null  int64
#  3   education                             48842 non-null  object
#  4   educational-num                       48842 non-null  int64
#  5   occupation                            48842 non-null  object
#  6   relationship                          48842 non-null  object
#  7   capital-gain                          48842 non-null  int64
#  8   capital-loss                          48842 non-null  int64
#  9   hours-per-week                        48842 non-null  int64
#  10  native-country                        48842 non-null  object
# ...

# %%
df2.to_csv('datasets/exercise.csv',index=False)

# %%
df=pd.DataFrame({'ProductName':['Bulb','Bulb','Fan','Fan'],
                'Type':['A','B','C','D'],
                'EC':[400.,300.,250.,300.]})

# %%
df
# Out:
#   ProductName Type     EC
# 0        Bulb    A  400.0
# 1        Bulb    B  300.0
# 2         Fan    C  250.0
# 3         Fan    D  300.0

# %%
df.groupby(['ProductName']).sum()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\3016294507.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['ProductName']).sum()
#                 EC
# ProductName
# Bulb         700.0
# Fan          550.0

# %%
df.groupby(['ProductName']).mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\1066161956.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['ProductName']).mean()
#                 EC
# ProductName
# Bulb         350.0
# Fan          275.0

# %%
df.groupby([df.ProductName,df.Type]).sum()
# Out:
#                      EC
# ProductName Type
# Bulb        A     400.0
#             B     300.0
# Fan         C     250.0
#             D     300.0

# %%
df.groupby(['ProductName']).agg(["mean",'sum'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\1449637652.py:1: FutureWarning: ['Type'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby(['ProductName']).agg(["mean",'sum'])
#                 EC
#               mean    sum
# ProductName
# Bulb         350.0  700.0
# Fan          275.0  550.0

# %%
name={'A':'Aung','B':'Baby','C':'Chit','D':'Denny','E':'Emily'}
married={'A':True,'B':False,'C':False,'D':True,'E':True}
town={'A':'Katha','B':'Indaw','C':'Katha','D':'Kawlin','E':'Wuntho'}
df=pd.DataFrame({'name':name,'married':married,'township':town})
df
# Out:
#     name  married township
# A   Aung     True    Katha
# B   Baby    False    Indaw
# C   Chit    False    Katha
# D  Denny     True   Kawlin
# E  Emily     True   Wuntho

# %%
df.groupby('township').sum()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13756\2295461730.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('township').sum()
#           married
# township
# Indaw           0
# Katha           1
# Kawlin          1
# Wuntho          1

# %%
name={'A':'Aung','B':'Baby','C':'Chit','D':'Denny','E':'Emily'}
married={'A':"True",'B':"False",'C':"False",'D':"True",'E':"True"}
town={'A':'Katha','B':'Indaw','C':'Katha','D':'Kawlin','E':'Wuntho'}
df=pd.DataFrame({'name':name,'married':married,'township':town})
df
# Out:
#     name married township
# A   Aung    True    Katha
# B   Baby   False    Indaw
# C   Chit   False    Katha
# D  Denny    True   Kawlin
# E  Emily    True   Wuntho
