# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df=pd.DataFrame({'A':np.random.normal(0,1,1000),
                'B':np.random.normal(-2,2,1000),
                'C':np.random.normal(5,4,1000)})
df
# Out:
#             A         B          C
# 0    0.107192 -2.589842   6.056162
# 1    1.707932  0.326750   3.285145
# 2   -0.129076  1.417806   0.524530
# 3    0.579754 -2.982003   3.078811
# 4    0.529871 -4.389538   7.235786
# ..        ...       ...        ...
# 995 -0.296335 -1.406582   2.129532
# 996 -0.217642 -5.388940   1.316614
# 997 -0.726701  0.806381   6.475261
# 998 -0.154140 -0.972687   1.376130
# 999 -2.334703 -5.296785  11.116985
#
# [1000 rows x 3 columns]

# %%
df.plot();

# %%
# df.plot.hist(alpha=0.5);
df.plot(kind='hist',alpha=0.5);

# %%
df.plot(kind='hist',alpha=0.5,stacked=True,bins=30);

# %%
df.plot(kind='hist',alpha=0.5,stacked=False,bins=30);

# %%
df.hist(alpha=0.5,bins=50);

# %%
df2=pd.DataFrame(np.random.rand(10,4),columns=list('abcd'))
df2
# Out:
#           a         b         c         d
# 0  0.586365  0.219820  0.506103  0.842340
# 1  0.160622  0.101701  0.955721  0.533779
# 2  0.088796  0.042181  0.878665  0.786031
# 3  0.969880  0.001475  0.326469  0.867857
# 4  0.017973  0.843022  0.197187  0.191217
# 5  0.597881  0.752492  0.658805  0.987132
# 6  0.948992  0.378759  0.821359  0.755496
# 7  0.463488  0.018467  0.352905  0.077278
# 8  0.362295  0.758072  0.983046  0.890039
# 9  0.119487  0.435628  0.346413  0.669392

# %%
df2.plot.area();

# %%
df2.plot.area(stacked=False);

# %%
df3=pd.DataFrame(3*np.random.rand(4,2),
                index=list('abcd'),
                columns=list('xy'))
df3
# Out:
#           x         y
# a  1.050905  1.378080
# b  1.119369  2.213507
# c  0.540600  1.801716
# d  1.496653  2.672210

# %%
df3.x.plot.pie();

# %%
df3.plot.pie(subplots=True,figsize=(8,4));
