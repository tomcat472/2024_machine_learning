# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.DataFrame({'X':np.random.normal(0,2,1000),
                'Y':np.random.normal(3,5,1000),
                'Z':np.random.normal(-4,10,1000)})
df
# Out:
#             X         Y          Z
# 0    2.559984 -1.175405  -8.742699
# 1   -1.124673 -7.969135 -16.266470
# 2    0.046360  1.011394  -6.331198
# 3   -0.644180 -2.410123  -3.420080
# 4    0.637534  0.935026  -1.366950
# ..        ...       ...        ...
# 995 -2.810709 -0.676545 -20.129295
# 996 -1.027832  4.228471 -13.273903
# 997  3.639458  9.052737  -6.737434
# 998 -2.311512 -0.285667  -6.180553
# 999 -0.907661  2.212283  -4.849196
#
# [1000 rows x 3 columns]

# %%
plt.figure(figsize=(4,3))
for col in df.columns:
    plt.hist(df[col],density=True,alpha=0.5,bins=30)
    sns.kdeplot(df[col],shade=True)

# %%
plt.figure(figsize=(4,4))
for col in df.columns:
    sns.displot(df[col])

# %%
with sns.axes_style('white'):
    sns.jointplot(x='X',y='Y',data=df,kind='kde')

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species')

# %%
plt.figure(figsize=(4,3))
# sns.relplot(x=iris.sepal_length,y=iris.sepal_width);
sns.relplot(x='sepal_length',y='sepal_width',data=iris);

# %%
sns.relplot(x='sepal_length',y='sepal_width',data=iris,hue='species',style='species');

# %%
sns.relplot(x='sepal_width',y='petal_length',
            data=iris,hue='sepal_length',style='species',
           markers=True);

# %%
sns.relplot(x='sepal_length',y='sepal_width',data=iris,kind='line',ci=False,
           hue='species',style='species',dashes=False,markers=True);

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.total_bill.isna().value_counts()
# Out:
# False    244
# Name: total_bill, dtype: int64

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,
            hue=tips.smoker,style=tips.smoker,col=tips.time);

# %%
df=sns.load_dataset('diamonds')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0  326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0  326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0  327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0  334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0  335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 26358   0.32  Very Good     H    VVS2   62.1   58.0  645.0  4.34  4.39  2.71
# 26359   0.32    Premium     G     VS1   60.6   60.0  645.0  4.40  4.44  2.68
# 26360   0.32    Premium     G     VS1   62.1   58.0  645.0  4.37  4.39  2.72
# 26361   0.32      Ideal     F     VS2   61.7   55.0  645.0  4.40  4.41  2.72
# 26362   0.32  Very Good     F     VS2   60.2    NaN    NaN   NaN   NaN   NaN
#
# [26363 rows x 10 columns]

# %%
# df.query("clarity=='VS2'")
sns.relplot(x="carat",y="price",hue="cut",
            style="color",col="clarity",col_wrap=2,
           kind='line',data=df)
